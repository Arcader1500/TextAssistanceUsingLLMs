# %% [markdown]
# # Module 1: Environment Setup
#
# Welcome! In this first step, we will prepare your machine for local LLM work.
#
# **Goal**: Install necessary libraries and verify that your GPU is detected.
#
# **Hardware Target**: 4GB VRAM GPU (NVIDIA) + 16GB RAM.
# **OS**: Windows.

# %% [markdown]
# ## 1. Install PyTorch
# We need PyTorch with CUDA support. Run the cell below.
# If you already have it installed, this might just say "Requirement already satisfied".

# %%
# !pip install torch torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 4.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.4 MB/s  0:00:00
# ...

# %% [markdown]
# ## 2. Install LLM & Optimization Libraries
# - `transformers`: To load models.
# - `accelerate`: Handles device placement.
# - `bitsandbytes`: For 4-bit quantization (critical for 4GB VRAM).
# - `peft`: Parameter-Efficient Fine-Tuning (for LoRA).
# - `trl`: Transformers Reinforcement Learning (easier trainer wrappers).
# - `scipy`: Often required.

# %%
# !pip install transformers accelerate bitsandbytes peft trl scipy
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/12.0 MB 11.0 MB/s eta 0:00:01
#    -------------------- ------------------- 6.3/12.0 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.2/12.0 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 17.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 566.1/566.1 kB 19.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 21.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/54.7 MB ? eta -:--:--
#    --- ------------------------------------ 4.2/54.7 MB 19.9 MB/s eta 0:00:03
#    ------ --------------------------------- 9.2/54.7 MB 21.9 MB/s eta 0:00:03
# ...

# %% [markdown]
# ## 3. Install RAG Libraries
# - `langchain` & `langchain-community`: Orchestration for RAG.
# - `chromadb`: Local vector database.
# - `sentence-transformers`: For creating embeddings.

# %%
# !pip install langchain langchain-community chromadb sentence-transformers ipywidgets
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 4.2 MB/s  0:00:00
# ...

# %% [markdown]
# ## 4. Verify Installation
# Let's check if CUDA is available and how much VRAM we have.
# If `torch.cuda.is_available()` returns `False`, you will not be able to follow the low-VRAM parts of this tutorial efficiently.

# %%
import torch
import bitsandbytes as bnb

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Device: {torch.cuda.get_device_name(0)}")
    total_mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"Total VRAM: {total_mem:.2f} GB")
    if total_mem < 4.0:
        print("\n⚠️ WARNING: Your VRAM is under 4GB. You might face OOM errors even with 4-bit.")
    else:
        print("\n✅ VRAM check passed (>= 4GB).")
else:
    print("\n❌ No GPU detected. This course requires an NVIDIA GPU.")
# Out:
# PyTorch version: 2.9.1+cu128
# CUDA Available: True
# CUDA Device: NVIDIA GeForce RTX 3050 Laptop GPU
# Total VRAM: 4.29 GB
#
# ✅ VRAM check passed (>= 4GB).
